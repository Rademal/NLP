# %%
from deeppavlov import configs
from deeppavlov import build_model
model = build_model("deeppavlov/configs/classifiers/insults_kaggle_bert.json", download = True)
# Out:
# 2022-11-22 17:47:04.93 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/deeppavlov_data/classifiers/insults_kaggle_torch_bert_v5.tar.gz download because of matching hashes
# 2022-11-22 17:47:05.223 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/datasets/insults_data.tar.gz download because of matching hashes
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\fcnjh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fcnjh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to
# [nltk_data]     C:\Users\fcnjh\AppData\Roaming\nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# ...

# %%
model('You are a fat pig')
# Out:
# ['Insult']

# %%
model('Fuck this thing')
# Out:
# ['Not Insult']

# %%
model('Shit happens')
# Out:
# ['Not Insult']

# %%
model('Jack is a piece of shit')
# Out:
# ['Insult']
